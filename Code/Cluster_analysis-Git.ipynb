# %% [markdown]
# # Cluster Analysis
#
# This notebook focuses on analysing the word clusters for a model. This includes visualizing fit of the clusters, formating them for manual inspection, and visualizing them using Multi Dimensional Scaling (MDS).
#
# We first import the libaries we will need throughout the project

# %%
#Import graphing utilities
# %matplotlib inline
import matplotlib.pyplot as plt

# Import useful mathematical libraries
import numpy as np
import pandas as pd

# Import useful Machine learning libraries
import gensim

# Import utility files
from utils import save_object,load_object, make_clustering_objects, make_frequency_dictionary

# %% [markdown]
# #### Setup directories
#
# If this is the first time doing this analysis,
# we first will set up all the directories we need
# to save and load the models we will be using

# %%
import os
directories = ['cluster-analysis','dictionaries']
for dirname in directories:
    if not os.path.exists(dirname):
        os.makedirs(dirname)

# %% [markdown]
# ### Set model name
#
# Before begining the rest of this project, we select a name for our model. This name will be used to save and load the files for this model

# %%
# Set the model we are going to be analyzing
model_name = "BipolarReddit"

# %% [markdown]
# ### Measure fit
#
# Now that we have initialized all we need for our analysis, we can procceed to examine the fit of each clustering.

# %%
# Load the fit and test point values
fit = load_object('objects/', model_name + "-words" + "-fit")
test_points = load_object('objects/', model_name + "-words" + "-test_points")

# %%
# Plot the fit for each size
plt.plot(test_points, fit, 'ro')
plt.axis([0, 400, 0, np.ceil(fit[0] + (1/10)*fit[0])])
plt.show()

# %% [markdown]
# ### Format for inspection
#
# After measuring the fit of each clustering, we can decide the number of clusters to use, and further focus on this clustering. To better examine this clustering, we convert the clustering into an readable csv here.

# %%
# Set the number of clusters to analyze
num_clusters = 100

# %%
# load the models
model = gensim.models.Word2Vec.load('models/' + model_name + '.model')
kmeans = load_object('clusters/', model_name + "-words-cluster_model-" + str(num_clusters))
WordsByFeatures = load_object('matricies/', model_name + '-' + 'WordsByFeatures')
# Out:
# /Users/Alex/anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
vocab_list = sorted(list(model.wv.vocab))

# %%
#BipR_WordFreq = {}
#for i in range(len(vocab_list)):
#    word = vocab_list[i]
#    freq = model.wv.vocab[word].count
#BipR_WordFreq.update({word:freq})
BipR_WordFreq = make_frequency_dictionary(model)
#save_object(BipR_WordFreq,'dictionaries/','BipR_WordFreq')
print(BipR_WordFreq)
# Out:
# {'aa': 60, 'aaand': 10, 'aap': 13, 'aaps': 16, 'abandon': 48, 'abandoned': 101, 'abandoning': 22, 'abandonment': 19, 'abc': 16, 'abilify': 843, 'abilify_mg': 57, 'abilify_wellbutrin': 14, 'abilities': 48, 'ability': 388, 'ability_function': 15, 'able': 2782, 'able_afford': 26, 'able_catch': 11, 'able_concentrate': 13, 'able_finish': 12, 'able_focus': 43, 'able_function': 39, 'able_get_bed': 16, 'able_handle': 48, 'able_hold': 23, 'able_hold_job': 16, 'able_identify': 12, 'able_maintain': 23, 'able_manage': 24, 'able_recognize': 13, 'able_relate': 19, 'abnormal': 81, 'abnormally': 15, 'abortion': 11, 'abroad': 57, 'abrupt': 14, 'abruptly': 37, 'absence': 64, 'absences': 35, 'absent': 38, 'absolute': 137, 'absolute_best': 10, 'absolute_hell': 11, 'absolute_worst': 23, 'absolutely': 612, 'absolutely_horrible': 15, 'absolutely_miserable': 13, 'absolutely_nothing': 60, 'absolutely_terrible': 16, 'absolutely_terrified': 11, 'absorb': 18, 'absorbing': 13, 'absorption': 11, 'abstain': 18, 'abstaining': 12, 'abstinence': 10, 'abstract': 26, 'absurd': 45, 'absurdly': 10, 'abt': 13, 'abundance': 10, 'abuse': 219, 'abused': 93, 'abuser': 26, 'abuses': 11, 'abusing': 43, 'abusive': 177, 'abusive_relationship': 32, 'abyss': 32, 'ac': 12, 'academia': 11, 'academic': 109, 'academic_probation': 15, 'academically': 37, 'academics': 30, 'accelerated': 11, 'accept': 406, 'accept_diagnosis': 19, 'accept_fact': 15, 'acceptable': 74, 'acceptance': 59, 'accepted': 239, 'accepting': 136, 'accepting_diagnosis': 16, 'accepting_new_patients': 10, 'accepts': 15, 'access': 209, 'accessible': 15, 'accident': 115, 'accidental': 12, 'accidentally': 111, 'accidentally_took': 16, 'accidents': 13, 'accommodate': 17, 'accommodating': 12, 'accommodation': 29, 'accommodations': 79, 'accompanied': 43, 'accompanies': 11, 'accomplish': 140, 'accomplish_anything': 32, 'accomplished': 85, 'accomplishing': 18, 'accomplishment': 47, 'accomplishments': 53, 'accord': 10, 'according': 163, 'accordingly': 20, 'account': 251, 'accountability': 25, 'accountable': 20, 'accounts': 65, 'accumulate': 12, 'accuracy': 13, 'accurate': 92, 'accurate_diagnosis': 10, 'accurately': 54, 'accusations': 18, 'accuse': 16, 'accused': 85, 'accusing': 20, 'accustomed': 16, 'ace': 10, 'ache': 42, 'aches': 33, 'achieve': 96, 'achieve_week': 16, 'achieved': 34, 'achievement': 32, 'achievements': 28, 'achieving': 32, 'aching': 26, 'achy': 15, 'acid': 72, 'acid_reflux': 11, 'acknowledge': 77, 'acknowledged': 28, 'acknowledgement': 10, 'acknowledging': 29, 'acne': 127, 'acquaintance': 16, 'acquaintances': 31, 'acquire': 15, 'acquired': 25, 'across': 142, 'across_country': 57, 'across_room': 12, 'across_street': 14, 'act': 467, 'act_like': 90, 'act_normal': 24, 'acted': 85, 'acted_like': 37, 'acting': 277, 'acting_crazy': 11, 'acting_like': 73, 'acting_weird': 12, 'action': 132, 'actions': 299, 'activated': 14, 'activating': 27, 'activation': 10, 'active': 224, 'actively': 99, 'actively_suicidal': 14, 'actively_trying': 17, 'activism': 10, 'activities': 161, 'activity': 132, 'actor': 22, 'actress': 12, 'acts': 89, 'actual': 304, 'actual_diagnosis': 14, 'actually': 3133, 'acupuncture': 12, 'acute': 65, 'acutely': 12, 'ad': 76, 'ada': 36, 'adamant': 25, 'adamantly': 10, 'adapt': 22, 'adapting': 10, 'add': 665, 'add_adhd': 23, 'add_list': 11, 'added': 282, 'added_mg': 32, 'added_wellbutrin': 12, 'adderal': 22, 'adderall': 440, 'adderall_xr': 18, 'addict': 73, 'addicted': 115, 'addiction': 254, 'addiction_problems': 15, 'addictions': 35, 'addictive': 46, 'addictive_personality': 20, 'addicts': 21, 'adding': 191, 'addition': 213, 'additional': 92, 'additionally': 48, 'address': 163, 'addressed': 59, 'addressing': 29, 'adds': 43, 'adenosine': 20, 'adequate': 43, 'aderall': 11, 'adhd': 845, 'adhd_ocd': 10, 'adhd_pi': 10, 'adjunct': 13, 'adjust': 111, 'adjust_meds': 17, 'adjust_new': 14, 'adjusted': 47, 'adjusting': 78, 'adjusting_meds': 11, 'adjusting_new': 15, 'adjustment': 44, 'adjustment_disorder': 11, 'ad ...

# %%
BipSOs = load_object('dictionaries/','BipSOs_WordFreq')
BipA = load_object('dictionaries/','BipAnalysis_WordFreq')
BipR = load_object('dictionaries/','BipR_WordFreq')

# %%
print(BipA['abandon'])
print(BipSOs['abandon'])
print(BipR['abandon'])
# Out:
# 64
# 18
# 48

# %%
clusters = make_clustering_objects(model, kmeans, vocab_list, WordsByFeatures)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ed675059c225> in <module>
# ----> 1 clusters = make_clustering_objects(model, kmeans, vocab_list, WordsByFeatures)
#
# /Volumes/Seagate Backup Plus Drive/REU/ChakravortiLawGemmell/MentalHealthInformaticsREU/analysis_template/utils.py in make_clustering_objects(word2vecModel, kmeans, vocab_list, WordByFeatureMat)
#     135         clusters.append( {'unique_words':0,'total_freq':0,'word_list':[]})
#     136
# --> 137     predictions = kmeans.predict(WordByFeatureMat)
#     138     for i in range(len(vocab_list)):
#     139         cluster   = predictions[i]
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in predict(self, X, sample_weight)
#    1074         check_is_fitted(self, 'cluster_centers_')
#    1075
# -> 1076         X = self._check_test_data(X)
#    1077         x_squared_norms = row_norms(X, squared=True)
#    1078         return _labels_inertia(X, sample_weight, x_squared_norms,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _check_test_data(self, X)
#     937             raise ValueError("Incorrect number of features. "
#     938                              "Got %d features, expected %d" % (
# --> 939                                  n_features, expected_n_features))
#     940
#     941         return X
#
# ValueError: Incorrect number of features. Got 300 features, expected 4

# %%
# Sort all the words in the words list
for cluster in clusters:
    cluster["word_list"].sort(key = lambda x:x[1], reverse = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c386d372f6c7> in <module>
#       1 # Sort all the words in the words list
# ----> 2 for cluster in clusters:
#       3     cluster["word_list"].sort(key = lambda x:x[1], reverse = True)
#
# NameError: name 'clusters' is not defined

# %%
# Set the number of words to display. The table with contain the top size_words_list words
size_words_list = 100
table = []
for i in range(len(clusters)):
    row = []
    row.append("cluster " + str(i+1))
    row.append(clusters[i]["total_freq"])
    row.append(clusters[i]["unique_words"])
    for j in range(size_words_list):
        try:
            row.append(clusters[i]["word_list"][j])
        except:
            break
    table.append(row)

# %%
import csv
with open('cluster-analysis/' + model_name + "-" + str(num_clusters) + '.csv', 'w') as csvfile:
    labels = ["Cluster Num", "total_freq", "unique_words"]
    for i in range(size_words_list):
        labels.append("Word" + str(i+1))
    labels.append("word_list")
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    [writer.writerow(r) for r in table]

# %% [markdown]
# #### Display Clusters Using MDS
#
# Produce a visualization of our clusters in a low dimensional space

# %%
# Fit the model to the clusters
from sklearn.manifold import MDS
mds = MDS().fit(kmeans.cluster_centers_)
print(kmeans.cluster_centers_)
# Out:
# [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.428      1.462      0.246     ]
#  [6.85       3.07368421 5.74210526 2.07105263]]

# %%
# Get the embeddings
embedding = mds.embedding_.tolist()
x = list(map(lambda x:x[0], embedding))
y = list(map(lambda x:x[1], embedding))
# Out:
# [0.735110588304785, 0.10532992070867053, 0.8022936274200625, -0.3783479540653951, -0.2592946785843378, 0.20783840846576573, -1.589196059639761, -0.5303199748997505, -0.19053305935216316, 0.2310783720513166, 3.1336095683608693, -0.340041879074233, 1.5362921805548473, 0.41656334151107904, -0.1439713719435903, -0.23858061625890636, -0.34425384063647246, -1.6247015678135532, 1.733434498780246, -2.8883739851835015, -0.5170651088229267, -0.5826492684451849, -0.4157209288817228, -0.04995403791867879, -0.797035609875094, -0.2035192263760224, -0.34312192072603004, -0.25993489883825033, 3.2732793172118737, 0.04955971938114049, 0.040652348560166, 1.3441007582318922, 1.599114553399274, 0.3103750782019815, 1.2960527678415679, -0.2725404383597468, -1.0171303059146113, -0.7546907863703811, -1.4480326852651633, 0.5736565040483671, 1.4412695205507962, 0.9456584306932055, 0.6797858348804903, 1.1478592232196005, -0.6589930606699319, -0.9234769739292961, -1.1756809314944543, 1.1957244337393294, 1.5636602869332736, 0.9608765269284375, -1.084948336583612, -0.0553001013782746, -1.2486040949307364, -0.7038594417319136, -0.24112996584437787, 0.6117736239305918, -0.5930646199179025, -0.7379201147527167, 0.7123869866925517, 0.4654038193326659, 0.0015358296747127144, 0.11554579152259749, -0.8613565367633406, -0.10239629785944417, 1.0057653705971386, -0.379889719571664, 0.8951183659865072, 0.6491319297421412, -0.1731256742523902, 1.4817813126795971, -0.7854574132637089, -1.2292851893379777, -3.494355948335914, -2.704538989208723, -2.389171298795983, -2.500972829183507, 0.4287392512761701, -0.25139576566195115, 0.4152150344123186, 0.016988699227950387, -1.2077657964314137, -0.39551193520480354, 0.2802924864939301, -1.4315388949712167, -0.12669779523683128, 2.7021612107908237, 0.5756721233953984, 1.4622653292418772, -1.1243105011553622, 1.148415984730949, -1.4347795979137248, 0.4951744543787531, 0.34315032796972156, 0.5876913067579792, -0.6451766544940147, 1.2789471519630933, 0.4424192033616137, 0.26923285802797986, 1.1481165099052364, 0.9936139100493265]

# %%
top_words= list(map(lambda x: x[0][0], map(lambda x: x["word_list"], clusters)))

# %%
# Plot the Graph with top words
plt.figure(figsize = (20, 10))
plt.plot(x, y, 'bo')
for i in range(len(top_words)):
    plt.annotate(top_words[i], (x[i], y[i]))
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import pylab as pl
iris = load_iris()
pca = PCA(n_components=2).fit(clusters[])
pca_2d = pca.transform(iris.data)
pl.figure('Reference Plot')
pl.scatter(pca_2d[:, 0], pca_2d[:, 1], c=iris.target)
kmeans = KMeans(n_clusters=3, random_state=111)
kmeans.fit(iris.data)
pl.figure('K-means with 3 clusters')
pl.scatter(pca_2d[:, 0], pca_2d[:, 1], c=kmeans.labels_)
pl.show()
# Out:
#   File "<ipython-input-24-72ecf095f5b1>", line 6
#     pca = PCA(n_components=2).fit(clusters[])
#                                            ^
# SyntaxError: invalid syntax
